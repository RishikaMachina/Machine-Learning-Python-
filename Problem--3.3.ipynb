# %%
import numpy as np

#parameters
rad = 10
thk = 5
sep = -5

#n data points,(x1,y1) are the coordinates of the top semi-circle
def generatedata(rad,thk,sep,n,x1=0,y1=0):
    # center of the top semi-circle
    X1 = x1
    Y1 = y1

    # center of the bottom semi-circle
    X2 = X1 + rad + thk / 2
    Y2 = Y1 - sep
    
    # data points in the top semi-circle
    top = []
    # data points in the bottom semi-circle
    bottom = []
    
    # parameters
    r1 = rad + thk
    r2 = rad
    
    cnt = 1
    while(cnt <= n):
        #uniformed generated points
        x = np.random.uniform(-r1,r1)
        y = np.random.uniform(-r1,r1)
        
        d = x**2 + y**2
        if(d >= r2**2 and d <= r1**2):
            if (y > 0):
                top.append([X1 + x,Y1 + y])
                cnt += 1
            else:
                bottom.append([X2 + x,Y2 + y])
                cnt += 1
        else:
            continue

    return top,bottom

# %%
import matplotlib.pyplot as plt
top,bottom = generatedata(rad,thk,sep,1000)

X1 = [i[0] for i in top]
Y1 = [i[1] for i in top]

X2 = [i[0] for i in bottom]
Y2 = [i[1] for i in bottom]

plt.scatter(X1,Y1,s = 1)
plt.scatter(X2,Y2,s = 1)
plt.show()

# %%
# pre-processing the data for (a)
x1 = [[1] + i + [1] for i in top]
x2 = [[1] + i + [-1] for i in bottom]
data = x1 + x2
    
data = np.array(data)
np.random.shuffle(data)

# %%
import random

def sign(x):
    if x >= 0:
        return 1
    else:
        return -1


def Judge(x,w):
    flag = 1
    for i in x:
        if sign(i[:3].dot(w))*i[-1] < 0:
            flag = 0
            break
    return flag 


#number of iterations
s = 0
w=np.array([-1,0,-3],dtype = float)
while (Judge(data,w) == 0):
    i = data[random.randint(0,2*500-1)]
    if sign(i[:3].dot(w))*i[-1]<0:
        w += i[-1]*i[:3]
        s += 1
        if(s==1):
            g=w
        if(s==100000):
            print("iteration count 1000000 exceeded")
            break

#w0+w1*x+w2*y=0
X3=np.arange(-15,20,0.1)
Y3=np.array([(X3[i]*w[1]+w[0])/(-w[2]) for i in range(len(X3))])

#target function is x+y=0
X4 = np.arange(-15,20,0.1)
Y4 = - X4

plt.scatter(X1,Y1,c = 'r',s = 1)
plt.scatter(X2,Y2,c = 'b',s = 1)
plt.plot(X3,Y3,'g',"Final Hypothesis")
plt.plot(X4,Y4,'r')
plt.title("3.3(a) and (c)")
plt.show()
# Out:
# iteration count 1000000 exceeded

# %%
N=2000

def error(data,w):
    e=0
    p=0
    for j in data:
        for d in range(0,3):
            p=p+sign((j[d]*w[d]))
        q=j[-1]
        if(p==q):
            n=0
        else:
            n=1
        e=e+n
    res=((1/N)*e)
    return res

# %%
for h in data:
    if (error(data,w)>=error(data,g)):
        w=g
        # updating w to w(t+1) if error is low
        s=0
        while (Judge(data,w) == 0):
            i = data[random.randint(0,2*100-1)]
            if sign(i[:3].dot(w))*i[-1]<0:
                w += i[-1]*i[:3]
                s += 1
            if(s==10000):
                #print("hi")
                break
print(s)
# Out:
# 100
